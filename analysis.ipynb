# %%
# The '!' tells the notebook to run a terminal command
# This ensures it installs into the exact environment you are currently using
# %pip install pandas numpy matplotlib seaborn scikit-learn joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the file you opened earlier
df = pd.read_csv('/Users/loki/Desktop/student_habits_performance.csv')
# Look at the first 5 rows to make sure it loaded correctly
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
#eda
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum().sum() #isna if a cell has data it make false and we can say .isna() check every cell if cell empty it marks with 1 other wise 0
#.sum() This adds up all those 1s for each column
#df.isna().sum().sum() is grandtotal of missing value in entire dataset
# Out:
# 91

# %%
df=df.dropna() #Look at my table. If any row has a missing piece of info (a blank cell), throw that entire row in the trash. Then, keep only the perfect rows as my updated data."

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# ...

# %%
df.describe(include="object").columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
categorical_cols = ["gender","part_time_job","diet_quality","parental_education_level","internet_quality","extracurricular_participation"]

# %%
for col in categorical_cols:
    print(f"Value counts for {col}: \n {df[col].value_counts()}")
# Out:
# Value counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# Value counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# Value counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# Value counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# Value counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# Value counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor = "black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    sns.countplot(data =df, x = col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation = 45)
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True , cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrisx")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features =['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in num_features:
    sns.scatterplot(data= df, x = feature,y="exam_score")
    plt.title(f"{feature} vs Exam Score")
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(data = df,x=col,y="exam_score")
    plt.title(f"Exam Score by{col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression ,  Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ['study_hours_per_day','attendance_percentage','mental_health_rating','sleep_hours','part_time_job']

# %%
target = "exam_score"

# %%
df_model = df[features + [target].copy()]

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# ...

# %%
le = LabelEncoder()

# %%
df_model["part_time_job"]=le.fit_transform(df_model["part_time_job"])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# ...

# %%
x = df_model[features]

# %%
y = df_model[target]

# %%
x_train, x_test , y_train , y_test = train_test_split(x,y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression":{
        "model": LinearRegression(),
        "params":{}
    },
    "DecisionTree":{
        "model": DecisionTreeRegressor(),
        "params": {"max_depth": [3,5,10],"min_samples_split":[2,5]}
    },
    "RandomForest": {
        "model": RandomForestRegressor(),
        "params":{"n_estimators":[50,100],"max_depth":[5,10]}

    }
}

# %%
best_models = []

# %%
for name, config in models.items():
    print(f"Training {name}")
    grid = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
    grid.fit(x_train, y_train)

    y_pred = grid.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_models.append({
        "model": name,
        "best_params": grid.best_params_,
        "rmse": rmse,
        "r2": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': 7.561868230269825,
#   'r2': 0.8088939460322133},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 2},
#   'rmse': 7.847516975480155,
#   'r2': 0.7941832281411122},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 5, 'n_estimators': 100},
#   'rmse': 7.597469411203528,
#   'r2': 0.8070902603207455}]

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  7.561868
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  7.597469
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 2}  7.847517
#
#          r2
# 0  0.808894
# 2  0.807090
# 1  0.794183

# %%
import joblib

best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   7.561868
# r2                     0.808894
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"] #.set_params(**best_row["best_params"])

# %%
final_model.fit(x,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(x_test)
# Out:
# array([ 84.70133971,  88.32100125,  47.41966756,  72.47549093,
#         81.14151653,  72.41928765,  78.00803167,  53.35891573,
#         97.04729563,  66.85495635,  41.50768325,  71.16711953,
#         48.17243843,  86.85962666,  68.48671733,  79.37860514,
#         70.5947591 ,  81.55564529, 102.20707529,  59.33617791,
#         84.20309395,  74.5910171 ,  52.76981731,  83.07636937,
#        115.32425793,  85.15391158,  46.24083769,  92.44727813,
#         55.03445016,  65.13307337,  70.71345219,  71.11753121,
#         82.19382145,  77.22484193,  83.1293514 ,  79.36878895,
#         65.73770789,  62.33964812,  76.84828965,  68.45406642,
#         98.48292768,  80.14418379,  51.45722985,  81.86159654,
#         53.21270007,  74.47177811,  56.4052808 ,  69.19275373,
#         73.63145597,  68.00488232, 102.05443373,  46.52666247,
#         86.41513985,  38.09300671,  50.87089394,  65.92873416,
#         70.10700083,  57.96780871,  63.02878767,  58.73592725,
# ...
